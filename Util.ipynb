# %%
import requests
from google.colab import files

# %%
def downloadFromGithub(url,dest,colab=False):
    """
    Downloads file from Github
    USE RAW link!!!
    
    Parameter
    String file - link of file
    String des - destination of file
    bool colab - Running on google colab
    """
 
    r = requests.get(url)
    with open(dest, 'wb') as f:  
        f.write(r.content)
        
    #if colab == True:
        #files.download(dest)

# %%
url = "https://raw.githubusercontent.com/leondz/emerging_entities_17/master/wnut17train.conll"
dest = r"C:\Users\alumno\Desktop\data"
downloadFromGithub(url,dest,True)
# Out:
# [Tag(token='@paulwalk', tag='O'), Tag(token='It', tag='O'), Tag(token="'s", tag='O'), Tag(token='the', tag='O'), Tag(token='view', tag='O'), Tag(token='from', tag='O'), Tag(token='where', tag='O'), Tag(token='I', tag='O'), Tag(token="'m", tag='O'), Tag(token='living', tag='O'), Tag(token='for', tag='O'), Tag(token='two', tag='O'), Tag(token='weeks', tag='O'), Tag(token='.', tag='O'), Tag(token='Empire', tag='B-location'), Tag(token='State', tag='I-location'), Tag(token='Building', tag='I-location'), Tag(token='=', tag='O'), Tag(token='ESB', tag='B-location'), Tag(token='.', tag='O'), Tag(token='Pretty', tag='O'), Tag(token='bad', tag='O'), Tag(token='storm', tag='O'), Tag(token='here', tag='O'), Tag(token='last', tag='O'), Tag(token='evening', tag='O'), Tag(token='.', tag='O'), Tag(token='From', tag='O'), Tag(token='Green', tag='O'), Tag(token='Newsfeed', tag='O'), Tag(token=':', tag='O'), Tag(token='AHFA', tag='B-group'), Tag(token='extends', tag='O'), Tag(token='deadline', tag='O'), Tag(token='for', tag='O'), Tag(token='Sage', tag='O'), Tag(token='Award', tag='O'), Tag(token='to', tag='O'), Tag(token='Nov', tag='O'), Tag(token='.', tag='O'), Tag(token='5', tag='O'), Tag(token='http://tinyurl.com/24agj38', tag='O'), Tag(token='Pxleyes', tag='B-corporation'), Tag(token='Top', tag='O'), Tag(token='50', tag='O'), Tag(token='Photography', tag='O'), Tag(token='Contest', tag='O'), Tag(token='Pictures', tag='O'), Tag(token='of', tag='O'), Tag(token='August', tag='O'), Tag(token='2010', tag='O'), Tag(token='...', tag='O'), Tag(token='http://bit.ly/bgCyZ0', tag='O'), Tag(token='#photography', tag='O'), Tag(token='today', tag='O'), Tag(token='is', tag='O'), Tag(token='my', tag='O'), Tag(token='last', tag='O'), Tag(token='day', tag='O'), Tag(token='at', tag='O'), Tag(token='the', tag='O'), Tag(token='office', tag='O'), Tag(token='.', tag='O'), Tag(token='4Dbling', tag='B-person'), Tag(token="'s", tag='O'), Tag(token='place', tag='O'), Tag(token='til', tag='O'), Tag(token='monday', tag='O'), Tag(token=',', tag='O'), Tag(token='party', tag='O'), Tag(token='party', tag='O'), Tag(token='party', tag='O'), Tag(token='.', tag='O'), Tag(token='&lt;', tag='O'), Tag(token='3', tag='O'), Tag(token='watching', tag='O'), Tag(token='the', tag='O'), Tag(token='VMA', tag='B-creative-work'), Tag(token='pre-show', tag='O'), Tag(token='again', tag='O'), Tag(token='lol', tag='O'), Tag(token='it', tag='O'), Tag(token='was', tag='O'), Tag(token="n't", tag='O'), Tag(token='even', tag='O'), Tag(token='a', tag='O'), Tag(token='good', tag='O'), Tag(token='show', tag='O'), Tag(token='the', tag='O'), Tag(token='first', tag='O'), Tag(token='time', tag='O'), Tag(token='...', tag='O'), Tag(token='so', tag='O'), Tag(token='bored', tag='O'), Tag(token='!', tag='O'), Tag(token='27', tag='O'), Tag(token='followers', tag='O'), Tag(token='!', tag='O'), Tag(token='30', tag='O'), Tag(token='followers', tag='O'), Tag(token='is', tag='O'), Tag(token='my', tag='O'), Tag(token='goal', tag='O'), Tag(token='for', tag='O'), Tag(token='today', tag='O'), Tag(token='!', tag='O'), Tag(token='This', tag='O'), Tag(token='is', tag='O'), Tag(token='the', tag='O'), Tag(token='2nd', tag='O'), Tag(token='hospital', tag='O'), Tag(token='ive', tag='O'), Tag(token='been', tag='O'), Tag(token='in', tag='O'), Tag(token='today', tag='O'), Tag(token=',', tag='O'), Tag(token='but', tag='O'), Tag(token='ive', tag='O'), Tag(token='just', tag='O'), Tag(token='seen', tag='O'), Tag(token='a', tag='O'), Tag(token='doctor', tag='O'), Tag(token='who', tag='O'), Tag(token='was', tag='O'), Tag(token='an', tag='O'), Tag(token='older', tag='O'), Tag(token='version', tag='O'), Tag(token='of', tag='O'), Tag(token='justin', tag='O'), Tag(token=":'", tag='O'), Tag(token=')', tag='O'), Tag(token='Friday', tag='O'), Tag(token='Night', tag='O'), Tag(token='Eats', tag='O'), Tag(token='http://twitpic.com/2pdvtr', tag='O'), Tag(token='Gotta', tag='O'), Tag(token='dress', tag='O'), Tag(token='up', tag='O'), Tag(token='for' ...
