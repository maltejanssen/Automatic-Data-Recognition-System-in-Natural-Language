# %%
import requests
from google.colab import files
from collections import namedtuple

# %%
def downloadFromGithub(url,dest,colab=False):
    """
    Downloads file from Github
    USE RAW link!!!
    
    Parameter
    String file - link of file
    String des - destination of file
    bool colab - Running on google colab
    """
 
    r = requests.get(url)
    with open(dest, 'wb') as f:  
        f.write(r.content)
        
    #if colab == True:
        #files.download(dest)
    
Tag = namedtuple("Tag", ["word", "tag"])    
def readTags(file):
    """
    Creates a list of tagged words from the corpus
    
    Parameter
    String file - dest of file from which sentences are to be read
    
    Return
    sentences - read tags
    """
    tags = []
    sep="\t"
    with open(file) as fp:
        for line in fp:
            line = line.strip()
            if line:
                line = line.split(sep)
                tags.append(Tag(*line))
    return tags
     
    
def readSentences(file):
    """
    Creates a list of sentences from the corpus
    
    Parameter
    String file - dest of file from which sentences are to be read
    
    Return
    sentences - read sentences
    """
    sentences = []
    sentence = ""
    sep="\t"
    with open(file) as fp:
        for line in fp:
            line = line.strip()
            if line:
                line = line.split(sep)
                sentence += line[0] 
                sentence += " "
            else:
                sentences.append(sentence)
                sentence = ""
    return sentences

# %%
url = "https://raw.githubusercontent.com/leondz/emerging_entities_17/master/wnut17train.conll"
dest = r"C:\Users\alumno\Desktop\data"
downloadFromGithub(url,dest,True)

tags = readTags(r"C:\Users\alumno\Desktop\data")
print(tags)

sentences = readSentences(r"C:\Users\alumno\Desktop\data")
print(sentences)
# Out:
# [Tag(word='@paulwalk', tag='O'), Tag(word='It', tag='O'), Tag(word="'s", tag='O'), Tag(word='the', tag='O'), Tag(word='view', tag='O'), Tag(word='from', tag='O'), Tag(word='where', tag='O'), Tag(word='I', tag='O'), Tag(word="'m", tag='O'), Tag(word='living', tag='O'), Tag(word='for', tag='O'), Tag(word='two', tag='O'), Tag(word='weeks', tag='O'), Tag(word='.', tag='O'), Tag(word='Empire', tag='B-location'), Tag(word='State', tag='I-location'), Tag(word='Building', tag='I-location'), Tag(word='=', tag='O'), Tag(word='ESB', tag='B-location'), Tag(word='.', tag='O'), Tag(word='Pretty', tag='O'), Tag(word='bad', tag='O'), Tag(word='storm', tag='O'), Tag(word='here', tag='O'), Tag(word='last', tag='O'), Tag(word='evening', tag='O'), Tag(word='.', tag='O'), Tag(word='From', tag='O'), Tag(word='Green', tag='O'), Tag(word='Newsfeed', tag='O'), Tag(word=':', tag='O'), Tag(word='AHFA', tag='B-group'), Tag(word='extends', tag='O'), Tag(word='deadline', tag='O'), Tag(word='for', tag='O'), Tag(word='Sage', tag='O'), Tag(word='Award', tag='O'), Tag(word='to', tag='O'), Tag(word='Nov', tag='O'), Tag(word='.', tag='O'), Tag(word='5', tag='O'), Tag(word='http://tinyurl.com/24agj38', tag='O'), Tag(word='Pxleyes', tag='B-corporation'), Tag(word='Top', tag='O'), Tag(word='50', tag='O'), Tag(word='Photography', tag='O'), Tag(word='Contest', tag='O'), Tag(word='Pictures', tag='O'), Tag(word='of', tag='O'), Tag(word='August', tag='O'), Tag(word='2010', tag='O'), Tag(word='...', tag='O'), Tag(word='http://bit.ly/bgCyZ0', tag='O'), Tag(word='#photography', tag='O'), Tag(word='today', tag='O'), Tag(word='is', tag='O'), Tag(word='my', tag='O'), Tag(word='last', tag='O'), Tag(word='day', tag='O'), Tag(word='at', tag='O'), Tag(word='the', tag='O'), Tag(word='office', tag='O'), Tag(word='.', tag='O'), Tag(word='4Dbling', tag='B-person'), Tag(word="'s", tag='O'), Tag(word='place', tag='O'), Tag(word='til', tag='O'), Tag(word='monday', tag='O'), Tag(word=',', tag='O'), Tag(word='party', tag='O'), Tag(word='party', tag='O'), Tag(word='party', tag='O'), Tag(word='.', tag='O'), Tag(word='&lt;', tag='O'), Tag(word='3', tag='O'), Tag(word='watching', tag='O'), Tag(word='the', tag='O'), Tag(word='VMA', tag='B-creative-work'), Tag(word='pre-show', tag='O'), Tag(word='again', tag='O'), Tag(word='lol', tag='O'), Tag(word='it', tag='O'), Tag(word='was', tag='O'), Tag(word="n't", tag='O'), Tag(word='even', tag='O'), Tag(word='a', tag='O'), Tag(word='good', tag='O'), Tag(word='show', tag='O'), Tag(word='the', tag='O'), Tag(word='first', tag='O'), Tag(word='time', tag='O'), Tag(word='...', tag='O'), Tag(word='so', tag='O'), Tag(word='bored', tag='O'), Tag(word='!', tag='O'), Tag(word='27', tag='O'), Tag(word='followers', tag='O'), Tag(word='!', tag='O'), Tag(word='30', tag='O'), Tag(word='followers', tag='O'), Tag(word='is', tag='O'), Tag(word='my', tag='O'), Tag(word='goal', tag='O'), Tag(word='for', tag='O'), Tag(word='today', tag='O'), Tag(word='!', tag='O'), Tag(word='This', tag='O'), Tag(word='is', tag='O'), Tag(word='the', tag='O'), Tag(word='2nd', tag='O'), Tag(word='hospital', tag='O'), Tag(word='ive', tag='O'), Tag(word='been', tag='O'), Tag(word='in', tag='O'), Tag(word='today', tag='O'), Tag(word=',', tag='O'), Tag(word='but', tag='O'), Tag(word='ive', tag='O'), Tag(word='just', tag='O'), Tag(word='seen', tag='O'), Tag(word='a', tag='O'), Tag(word='doctor', tag='O'), Tag(word='who', tag='O'), Tag(word='was', tag='O'), Tag(word='an', tag='O'), Tag(word='older', tag='O'), Tag(word='version', tag='O'), Tag(word='of', tag='O'), Tag(word='justin', tag='O'), Tag(word=":'", tag='O'), Tag(word=')', tag='O'), Tag(word='Friday', tag='O'), Tag(word='Night', tag='O'), Tag(word='Eats', tag='O'), Tag(word='http://twitpic.com/2pdvtr', tag='O'), Tag(word='Gotta', tag='O'), Tag(word='dress', tag='O'), Tag(word='up', tag='O'), Tag(word='for', tag='O'), Tag(word='london', tag='O'), Tag(word='fashion', tag='O'), Tag(word='week', tag='O'), Tag(word='and', tag='O'), Tag(word='party ...
